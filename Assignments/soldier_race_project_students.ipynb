# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data *
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
#%matplotlib notebook
plt.rcParams["figure.figsize"] = (10,6)
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")
pd.set_option('display.float_format', lambda x: '%.3f' % x)
 #install -c conda-forge dataprep
#from dataprep.eda import plot
#from dataprep.datasets import load_dataset

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %%
female = pd.read_csv("ANSUR II FEMALE Public.csv", encoding='latin-1')
male = pd.read_csv("ANSUR II MALE Public.csv", encoding='latin-1')

# %%
female.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# 2                      237               196                397
# 3                      240               188                384
# 4                      217               182                378
#
#    bicepscircumferenceflexed  ...                  Branch  PrimaryMOS  \
# 0                        315  ...          Combat Support         92Y
# 1                        272  ...  Combat Service Support         25U
# 2                        300  ...  Combat Service Support         35D
# 3                        364  ...  Combat Service Support         25U
# 4                        320  ...             Combat Arms         42A
#
#    SubjectsBirthLocation  SubjectNumericRace           Ethnicity  DODRace  \
# 0                Germany                   2                 NaN        2
# 1             California                   3             Mexican        3
# 2                  Texas                   1                 NaN        1
# 3   District of Columbia                   8  Caribbean Islander        2
# 4                  Texas                   1                 NaN        1
#
#    Age  Heightin  Weightlbs  WritingPreference
# 0   26        61        142         Right hand
# 1   21        64        120         Right hand
# 2   23        68        147         Right hand
# 3   22        66        175         Right hand
# 4   45        63        195         Right hand
#
# [5 rows x 108 columns]

# %%
female.shape
# Out:
# (1986, 108)

# %%
female = female.rename({'SubjectId': 'subjectid'}, axis=1)

# %%
female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Columns: 108 entries, subjectid to WritingPreference
# dtypes: int64(99), object(9)
# memory usage: 1.6+ MB

# %%
female.isna().sum().any()
# Out:
# True

# %%
male.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# 2                      256               196                427
# 3                      262               199                401
# 4                      267               224                435
#
#    bicepscircumferenceflexed  ...                  Branch  PrimaryMOS  \
# 0                        369  ...             Combat Arms         19D
# 1                        338  ...          Combat Support         68W
# 2                        408  ...          Combat Support         68W
# 3                        359  ...  Combat Service Support         88M
# 4                        356  ...  Combat Service Support         92G
#
#    SubjectsBirthLocation  SubjectNumericRace  Ethnicity  DODRace  Age  \
# 0           North Dakota                   1        NaN        1   41
# 1               New York                   1        NaN        1   35
# 2               New York                   2        NaN        2   42
# 3              Wisconsin                   1        NaN        1   31
# 4         North Carolina                   2        NaN        2   21
#
#    Heightin  Weightlbs  WritingPreference
# 0        71        180         Right hand
# 1        68        160          Left hand
# 2        68        205          Left hand
# 3        66        175         Right hand
# 4        77        213         Right hand
#
# [5 rows x 108 columns]

# %%
male.shape
# Out:
# (4082, 108)

# %%
male.isna().sum().any()
# Out:
# True

# %% [markdown]
# ## Explore Data

# %%
df = pd.concat([female, male], ignore_index = True)

# %%
df.shape
# Out:
# (6068, 108)

# %%
df.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# 2                      237               196                397
# 3                      240               188                384
# 4                      217               182                378
#
#    bicepscircumferenceflexed  ...                  Branch  PrimaryMOS  \
# 0                        315  ...          Combat Support         92Y
# 1                        272  ...  Combat Service Support         25U
# 2                        300  ...  Combat Service Support         35D
# 3                        364  ...  Combat Service Support         25U
# 4                        320  ...             Combat Arms         42A
#
#    SubjectsBirthLocation  SubjectNumericRace           Ethnicity  DODRace  \
# 0                Germany                   2                 NaN        2
# 1             California                   3             Mexican        3
# 2                  Texas                   1                 NaN        1
# 3   District of Columbia                   8  Caribbean Islander        2
# 4                  Texas                   1                 NaN        1
#
#    Age  Heightin  Weightlbs  WritingPreference
# 0   26        61        142         Right hand
# 1   21        64        120         Right hand
# 2   23        68        147         Right hand
# 3   22        66        175         Right hand
# 4   45        63        195         Right hand
#
# [5 rows x 108 columns]

# %%
df.drop(['Date', 'Component', 'Installation', 'Branch', 'PrimaryMOS', 'SubjectNumericRace', 'Weightlbs', "Ethnicity", 'Heightin', 'subjectid'],axis=1, inplace=True)

# %%
df.head()
# Out:
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                             231            1282                    301
# 1                             194            1379                    320
# 2                             183            1369                    329
# 3                             261            1356                    306
# 4                             309            1303                    308
#
#    anklecircumference  axillaheight  balloffootcircumference  \
# 0                 204          1180                      222
# 1                 207          1292                      225
# 2                 233          1271                      237
# 3                 214          1250                      240
# 4                 214          1210                      217
#
#    balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 0               177                373                        315
# 1               178                372                        272
# 2               196                397                        300
# 3               188                384                        364
# 4               182                378                        320
#
#    bicristalbreadth  ...  waistfrontlengthsitting  waistheightomphalion  \
# 0               263  ...                      345                   942
# 1               250  ...                      329                  1032
# 2               276  ...                      367                  1035
# 3               276  ...                      371                   999
# 4               336  ...                      380                   911
#
#    weightkg  wristcircumference  wristheight  Gender  SubjectsBirthLocation  \
# 0       657                 152          756  Female                Germany
# 1       534                 155          815  Female             California
# 2       663                 162          799  Female                  Texas
# 3       782                 173          818  Female   District of Columbia
# 4       886                 152          762  Female                  Texas
#
#    DODRace  Age  WritingPreference
# 0        2   26         Right hand
# 1        3   21         Right hand
# 2        1   23         Right hand
# 3        2   22         Right hand
# 4        1   45         Right hand
#
# [5 rows x 98 columns]

# %%
#plot(df)

# %%
df = df[df.DODRace < 4]

# %%
df.DODRace.value_counts()
# Out:
# 1    3792
# 2    1298
# 3     679
# Name: DODRace, dtype: int64

# %%
df.shape
# Out:
# (5769, 98)

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5769 entries, 0 to 6067
# Data columns (total 98 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   abdominalextensiondepthsitting  5769 non-null   int64
#  1   acromialheight                  5769 non-null   int64
#  2   acromionradialelength           5769 non-null   int64
#  3   anklecircumference              5769 non-null   int64
#  4   axillaheight                    5769 non-null   int64
#  5   balloffootcircumference         5769 non-null   int64
#  6   balloffootlength                5769 non-null   int64
#  7   biacromialbreadth               5769 non-null   int64
#  8   bicepscircumferenceflexed       5769 non-null   int64
#  9   bicristalbreadth                5769 non-null   int64
#  10  bideltoidbreadth                5769 non-null   int64
#  11  bimalleolarbreadth              5769 non-null   int64
#  12  bitragionchinarc                5769 non-null   int64
#  13  bitragionsubmandibulararc       5769 non-null   int64
#  14  bizygomaticbreadth              5769 non-null   int64
#  15  buttockcircumference            5769 non-null   int64
#  16  buttockdepth                    5769 non-null   int64
#  17  buttockheight                   5769 non-null   int64
#  18  buttockkneelength               5769 non-null   int64
#  19  buttockpopliteallength          5769 non-null   int64
#  20  calfcircumference               5769 non-null   int64
#  21  cervicaleheight                 5769 non-null   int64
#  22  chestbreadth                    5769 non-null   int64
#  23  chestcircumference              5769 non-null   int64
#  24  chestdepth                      5769 non-null   int64
#  25  chestheight                     5769 non-null   int64
#  26  crotchheight                    5769 non-null   int64
#  27  crotchlengthomphalion           5769 non-null   int64
#  28  crotchlengthposterioromphalion  5769 non-null   int64
#  29  earbreadth                      5769 non-null   int64
#  30  earlength                       5769 non-null   int64
#  31  earprotrusion                   5769 non-null   int64
#  32  elbowrestheight                 5769 non-null   int64
#  33  eyeheightsitting                5769 non-null   int64
#  34  footbreadthhorizontal           5769 non-null   int64
#  35  footlength                      5769 non-null   int64
#  36  forearmcenterofgriplength       5769 non-null   int64
#  37  forearmcircumferenceflexed      5769 non-null   int64
#  38  forearmforearmbreadth           5769 non-null   int64
#  39  forearmhandlength               5769 non-null   int64
#  40  functionalleglength             5769 non-null   int64
#  41  handbreadth                     5769 non-null   int64
#  42  handcircumference               5769 non-null   int64
#  43  handlength                      5769 non-null   int64
#  44  headbreadth                     5769 non-null   int64
#  45  headcircumference               5769 non-null   int64
#  46  headlength                      5769 non-null   int64
#  47  heelanklecircumference          5769 non-null   int64
#  48  heelbreadth                     5769 non-null   int64
#  49  hipbreadth                      5769 non-null   int64
#  50  hipbreadthsitting               5769 non-null   int64
#  51  iliocristaleheight              5769 non-null   int64
#  52  interpupillarybreadth           5769 non-null   int64
#  53  interscyei                      5769 non-null   int64
#  54  interscyeii                     5769 non-null   int64
#  55  kneeheightmidpatella            5769 non-null   int64
#  56  kneeheightsitting               5769 non-null   int64
#  57  lateralfemoralepicondyleheight  5769 non-null   int64
#  58  lateralmalleolusheight          5769 non-null   int64
#  59  lowerthighcircumference         5769 non-null   int64
#  60  mentonsellionlength             5769 non-null   int64
#  61  neckcircumference               5769 non-null   int64
#  62  neckcircumferencebase           5769 non-null   int64
#  63  overheadfingertipreachsitting   5769 non-null   int64
#  64  palmlength                      5769 non-null   int64
#  65  poplitealheight                 5769 non-null   int64
#  66  radialestylionlength            5769 non-null   int64
#  67  shouldercircumference           5769 non-null   int64
#  68  shoulderelbowlength             5769 non-null   int64
#  69  shoulderlength                  5769 non-null   int64
#  70  sittingheight                   5769 non-null   int64
#  71  sleevelengthspinewrist          5769 non-null   int64
#  72  sleeveoutseam                   5769 non-null   int64
#  73  span                            5769 non-null   int64
#  74  stature                         5769 non-null   int64
#  75  suprasternaleheight             5769 non-null   int64
#  76  tenthribheight                  5769 non-null   int64
#  77  thighcircumference              5769 non-null   int64
#  78  thighclearance                  5769 non-null   int64
#  79  thumbtipreach                   5769 non-null   int64
#  80  tibialheight                    5769 non-null   int64
#  81  tragiontopofhead                5769 non-null   int64
#  82  trochanterionheight             5769 non-null   int64
#  83  verticaltrunkcircumferenceusa   5769 non-null   int64
#  84  waistbacklength                 5769 non-null   int64
#  85  waistbreadth                    5769 non-null   int64
#  86  waistcircumference              5769 non-null   int64
#  87  waistdepth                      5769 non-null   int64
#  88  waistfrontlengthsitting         5769 non-null   int64
#  89  waistheightomphalion            5769 non-null   int64
#  90  weightkg                        5769 non-null   int64
#  91  wristcircumference              5769 non-null   int64
#  92  wristheight                     5769 non-null   int64
#  93  Gender                          5769 non-null   object
#  94  SubjectsBirthLocation           5769 non-null   object
#  95  DODRace                         5769 non-null   int64
#  96  Age                             5769 non-null   int64
#  97  WritingPreference               5769 non-null   object
# dtypes: int64(95), object(3)
# memory usage: 4.4+ MB

# %%
def show_nans(df, limit):
    missing = df.isnull().sum()*100/df.shape[0]
    return missing.loc[lambda x : x >= limit]

show_nans(df,20)
# Out:
# Series([], dtype: float64)

# %%
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 150

# %%
df
# Out:
#       abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                                231            1282                    301
# 1                                194            1379                    320
# 2                                183            1369                    329
# 3                                261            1356                    306
# 4                                309            1303                    308
# ...                              ...             ...                    ...
# 6063                             235            1353                    312
# 6064                             247            1473                    336
# 6065                             264            1394                    313
# 6066                             203            1417                    327
# 6067                             327            1523                    358
#
#       anklecircumference  axillaheight  balloffootcircumference  \
# 0                    204          1180                      222
# 1                    207          1292                      225
# 2                    233          1271                      237
# 3                    214          1250                      240
# 4                    214          1210                      217
# ...                  ...           ...                      ...
# 6063                 216          1263                      228
# 6064                 234          1346                      253
# 6065                 227          1280                      245
# 6066                 223          1314                      250
# 6067                 226          1408                      269
#
#       balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 0                  177                373                        315
# 1                  178                372                        272
# 2                  196                397                        300
# 3                  188                384                        364
# 4                  182                378                        320
# ...                ...                ...                        ...
# 6063               193                384                        318
# 6064               196                428                        374
# 6065               193                407                        367
# 6066               196                419                        365
# 6067               225                442                        379
#
#       bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  \
# 0                  263               466                  65
# 1                  250               430                  64
# 2                  276               450                  69
# 3                  276               484                  68
# 4                  336               525                  67
# ...                ...               ...                 ...
# 6063               241               457                  70
# 6064               284               536                  76
# 6065               271               501                  74
# 6066               271               493                  75
# 6067               275               531                  81
#
#       bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  \
# 0                  338                        301                 141
# 1                  294                        270                 126
# 2                  309                        270                 128
# 3                  340                        294                 144
# 4                  300                        295                 135
# ...                ...                        ...                 ...
# 6063               321                        301                 137
# 6064               319                        316                 135
# 6065               323                        316                 142
# 6066               342                        327                 138
# 6067               359                        364                 150
#
#       buttockcircumference  buttockdepth  buttockheight  buttockkneelength  \
# 0                     1011           223            836                587
# 1                      893           186            900                583
# 2                      987           204            861                583
# 3                     1012           253            897                599
# 4                     1281           284            811                607
# ...                    ...           ...            ...                ...
# 6063                   917           231            878                587
# 6064                  1049           252            899                632
# 6065                  1038           276            857                614
# 6066                   929           209            898                598
# 6067                  1009           254            981                659
#
#       buttockpopliteallength  calfcircumference  cervicaleheight  \
# 0                        476                360             1336
# 1                        483                350             1440
# 2                        466                384             1451
# 3                        471                372             1430
# 4                        467                433             1362
# ...                      ...                ...              ...
# 6063                     497                345             1444
# 6064                     517                399             1533
# 6065                     502                378             1469
# 6066                     499                389             1483
# 6067                     550                396             1595
#
#       chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  \
# 0              274                 922         245         1095           759
# 1              261                 839         206         1234           835
# 2              287                 874         223         1226           821
# 3              269                1008         285         1170           804
# 4              305                1089         290         1112           726
# ...            ...                 ...         ...          ...           ...
# 6063           266                 954         238         1231           807
# 6064           323                1072         242         1301           848
# 6065           290                1045         247         1263           787
# 6066           284                 984         228         1271           846
# 6067           308                1144         281         1349           931
#
#       crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  \
# 0                       557                             310          35
# 1                       549                             329          32
# 2                       643                             374          36
# 3                       640                             351          38
# 4                       686                             356          34
# ...                     ...                             ...         ...
# 6063                    606                             306          36
# 6064                    695                             378          35
# 6065                    668                             337          38
# 6066                    603                             314          37
# 6067                    637                             313          36
#
#       earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0            65             16              220               713
# 1            60             23              208               726
# 2            65             26              204               790
# 3            62             22              244               775
# 4            65             18              233               732
# ...         ...            ...              ...               ...
# 6063         61             22              195               762
# 6064         60             20              299               807
# 6065         62             26              257               784
# 6066         61             22              237               782
# 6067         61             24              214               780
#
#       footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                        91         246                        316
# 1                        91         249                        341
# 2                       100         265                        343
# 3                        97         265                        331
# 4                        88         247                        339
# ...                     ...         ...                        ...
# 6063                     95         255                        329
# 6064                    103         263                        341
# 6065                    101         263                        340
# 6066                     98         266                        322
# 6067                    111         295                        377
#
#       forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                            265                    517                432
# 1                            247                    468                463
# 2                            262                    488                469
# 3                            309                    529                455
# 4                            260                    596                447
# ...                          ...                    ...                ...
# 6063                         277                    533                460
# 6064                         327                    600                476
# 6065                         312                    540                455
# 6066                         299                    552                461
# 6067                         317                    601                519
#
#       functionalleglength  handbreadth  handcircumference  handlength  \
# 0                    1028           75                182         184
# 1                    1117           78                187         189
# 2                    1060           84                198         195
# 3                    1069           80                192         186
# 4                    1039           78                183         187
# ...                   ...          ...                ...         ...
# 6063                 1073           81                193         182
# 6064                 1088           94                222         191
# 6065                 1045           83                207         183
# 6066                 1091           92                218         192
# 6067                 1212           95                223         205
#
#       headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0             141                548         191                     314
# 1             138                535         180                     307
# 2             146                588         207                     331
# 3             153                593         206                     332
# 4             140                522         181                     308
# ...           ...                ...         ...                     ...
# 6063          151                554         187                     323
# 6064          149                558         196                     327
# 6065          148                555         194                     340
# 6066          150                560         197                     326
# 6067          153                615         220                     358
#
#       heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0              69         345                388                 966
# 1              60         315                335                1048
# 2              70         356                399                1043
# 3              68         337                402                1029
# 4              63         448                499                 964
# ...           ...         ...                ...                 ...
# 6063           69         301                353                1025
# 6064           67         356                395                1057
# 6065           74         334                362                1032
# 6066           65         320                352                1050
# 6067           72         339                371                1127
#
#       interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                       645         363          399                   435
# 1                       595         340          375                   483
# 2                       655         345          399                   470
# 3                       655         392          435                   469
# 4                       635         428          435                   440
# ...                     ...         ...          ...                   ...
# 6063                    595         405          422                   474
# 6064                    590         468          473                   491
# 6065                    560         434          450                   464
# 6066                    630         440          445                   480
# 6067                    695         457          482                   544
#
#       kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                   496                             447
# 1                   532                             492
# 2                   530                             469
# 3                   520                             478
# 4                   491                             441
# ...                 ...                             ...
# 6063                523                             476
# 6064                565                             510
# 6065                527                             466
# 6066                542                             489
# 6067                596                             536
#
#       lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  \
# 0                         55                      404                  118
# 1                         69                      334                  115
# 2                         64                      401                  135
# 3                         67                      402                  118
# 4                         63                      479                  114
# ...                      ...                      ...                  ...
# 6063                      68                      371                  123
# 6064                      67                      420                  117
# 6065                      71                      413                  118
# 6066                      70                      364                  123
# 6067                      70                      410                  136
#
#       neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  \
# 0                   335                    368                           1268
# 1                   302                    345                           1389
# 2                   325                    369                           1414
# 3                   357                    386                           1329
# 4                   340                    358                           1350
# ...                 ...                    ...                            ...
# 6063                378                    427                           1304
# 6064                392                    430                           1433
# 6065                416                    444                           1310
# 6066                387                    414                           1388
# 6067                439                    477                           1399
#
#       palmlength  poplitealheight  radialestylionlength  \
# 0            113              362                   235
# 1            110              426                   259
# 2            122              398                   258
# 3            115              394                   250
# 4            116              345                   242
# ...          ...              ...                   ...
# 6063         112              418                   259
# 6064         114              447                   265
# 6065         110              407                   257
# 6066         115              432                   254
# 6067         116              464                   295
#
#       shouldercircumference  shoulderelbowlength  shoulderlength  \
# 0                      1062                  327             148
# 1                      1014                  346             142
# 2                      1049                  362             164
# 3                      1121                  333             157
# 4                      1151                  329             156
# ...                     ...                  ...             ...
# 6063                   1096                  348             150
# 6064                   1199                  356             146
# 6065                   1181                  333             135
# 6066                   1162                  358             154
# 6067                   1231                  386             152
#
#       sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  \
# 0               803                     809            513  1647     1560
# 1               835                     810            575  1751     1665
# 2               904                     855            568  1779     1711
# 3               875                     815            536  1708     1660
# 4               824                     810            559  1702     1572
# ...             ...                     ...            ...   ...      ...
# 6063            883                     865            568  1688     1688
# 6064            938                     903            606  1818     1765
# 6065            895                     860            571  1642     1690
# 6066            900                     874            576  1760     1718
# 6067            896                     955            638  1885     1828
#
#       suprasternaleheight  tenthribheight  thighcircumference  thighclearance  \
# 0                    1280            1013                 622             174
# 1                    1372            1107                 524             152
# 2                    1383            1089                 577             164
# 3                    1358            1065                 679             187
# 4                    1292            1030                 766             197
# ...                   ...             ...                 ...             ...
# 6063                 1368            1079                 579             162
# 6064                 1456            1146                 662             171
# 6065                 1384            1096                 605             178
# 6066                 1405            1116                 544             170
# 6067                 1500            1208                 622             196
#
#       thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  \
# 0               736           430               110                  844
# 1               771           475               125                  901
# 2               814           458               129                  882
# 3               736           463               125                  866
# 4               766           429               116                  800
# ...             ...           ...               ...                  ...
# 6063            758           447               140                  869
# 6064            785           472               135                  886
# 6065            750           439               127                  858
# 6066            779           453               118                  886
# 6067            861           509               135                  970
#
#       verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  \
# 0                              1488              406           295
# 1                              1470              422           254
# 2                              1542              419           269
# 3                              1627              451           302
# 4                              1698              452           405
# ...                             ...              ...           ...
# 6063                           1557              442           279
# 6064                           1715              475           351
# 6065                           1682              483           333
# 6066                           1589              430           293
# 6067                           1764              511           354
#
#       waistcircumference  waistdepth  waistfrontlengthsitting  \
# 0                    850         217                      345
# 1                    708         168                      329
# 2                    727         159                      367
# 3                    923         235                      371
# 4                   1163         300                      380
# ...                  ...         ...                      ...
# 6063                 816         210                      347
# 6064                 978         235                      385
# 6065                 991         258                      353
# 6066                 783         192                      350
# 6067                1080         294                      389
#
#       waistheightomphalion  weightkg  wristcircumference  wristheight  Gender  \
# 0                      942       657                 152          756  Female
# 1                     1032       534                 155          815  Female
# 2                     1035       663                 162          799  Female
# 3                      999       782                 173          818  Female
# 4                      911       886                 152          762  Female
# ...                    ...       ...                 ...          ...     ...
# 6063                  1016       675                 163          778    Male
# 6064                  1082       896                 178          873    Male
# 6065                  1011       832                 178          822    Male
# 6066                  1062       731                 172          837    Male
# 6067                  1119       985                 182          894    Male
#
#      SubjectsBirthLocation  DODRace  Age WritingPreference
# 0                  Germany        2   26        Right hand
# 1               California        3   21        Right hand
# 2                    Texas        1   23        Right hand
# 3     District of Columbia        2   22        Right hand
# 4                    Texas        1   45        Right hand
# ...                    ...      ...  ...               ...
# 6063              Colorado        1   22        Right hand
# 6064              Oklahoma        1   22        Right hand
# 6065              Oklahoma        1   23        Right hand
# 6066              Oklahoma        1   22        Right hand
# 6067              Oklahoma        1   38        Right hand
#
# [5769 rows x 98 columns]

# %%
sns.countplot(df.DODRace);

# %%
df["DODRace"].replace({1:"White", 2: "Black", 3: "Hispanic"}, inplace=True)

# %%
df.head()
# Out:
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                             231            1282                    301
# 1                             194            1379                    320
# 2                             183            1369                    329
# 3                             261            1356                    306
# 4                             309            1303                    308
#
#    anklecircumference  axillaheight  balloffootcircumference  \
# 0                 204          1180                      222
# 1                 207          1292                      225
# 2                 233          1271                      237
# 3                 214          1250                      240
# 4                 214          1210                      217
#
#    balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 0               177                373                        315
# 1               178                372                        272
# 2               196                397                        300
# 3               188                384                        364
# 4               182                378                        320
#
#    bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  \
# 0               263               466                  65               338
# 1               250               430                  64               294
# 2               276               450                  69               309
# 3               276               484                  68               340
# 4               336               525                  67               300
#
#    bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  \
# 0                        301                 141                  1011
# 1                        270                 126                   893
# 2                        270                 128                   987
# 3                        294                 144                  1012
# 4                        295                 135                  1281
#
#    buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  \
# 0           223            836                587                     476
# 1           186            900                583                     483
# 2           204            861                583                     466
# 3           253            897                599                     471
# 4           284            811                607                     467
#
#    calfcircumference  cervicaleheight  chestbreadth  chestcircumference  \
# 0                360             1336           274                 922
# 1                350             1440           261                 839
# 2                384             1451           287                 874
# 3                372             1430           269                1008
# 4                433             1362           305                1089
#
#    chestdepth  chestheight  crotchheight  crotchlengthomphalion  \
# 0         245         1095           759                    557
# 1         206         1234           835                    549
# 2         223         1226           821                    643
# 3         285         1170           804                    640
# 4         290         1112           726                    686
#
#    crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 0                             310          35         65             16
# 1                             329          32         60             23
# 2                             374          36         65             26
# 3                             351          38         62             22
# 4                             356          34         65             18
#
#    elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 0              220               713                     91         246
# 1              208               726                     91         249
# 2              204               790                    100         265
# 3              244               775                     97         265
# 4              233               732                     88         247
#
#    forearmcenterofgriplength  forearmcircumferenceflexed  \
# 0                        316                         265
# 1                        341                         247
# 2                        343                         262
# 3                        331                         309
# 4                        339                         260
#
#    forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  \
# 0                    517                432                 1028           75
# 1                    468                463                 1117           78
# 2                    488                469                 1060           84
# 3                    529                455                 1069           80
# 4                    596                447                 1039           78
#
#    handcircumference  handlength  headbreadth  headcircumference  headlength  \
# 0                182         184          141                548         191
# 1                187         189          138                535         180
# 2                198         195          146                588         207
# 3                192         186          153                593         206
# 4                183         187          140                522         181
#
#    heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  \
# 0                     314           69         345                388
# 1                     307           60         315                335
# 2                     331           70         356                399
# 3                     332           68         337                402
# 4                     308           63         448                499
#
#    iliocristaleheight  interpupillarybreadth  interscyei  interscyeii  \
# 0                 966                    645         363          399
# 1                1048                    595         340          375
# 2                1043                    655         345          399
# 3                1029                    655         392          435
# 4                 964                    635         428          435
#
#    kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                   435                496                             447
# 1                   483                532                             492
# 2                   470                530                             469
# 3                   469                520                             478
# 4                   440                491                             441
#
#    lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  \
# 0                      55                      404                  118
# 1                      69                      334                  115
# 2                      64                      401                  135
# 3                      67                      402                  118
# 4                      63                      479                  114
#
#    neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  \
# 0                335                    368                           1268
# 1                302                    345                           1389
# 2                325                    369                           1414
# 3                357                    386                           1329
# 4                340                    358                           1350
#
#    palmlength  poplitealheight  radialestylionlength  shouldercircumference  \
# 0         113              362                   235                   1062
# 1         110              426                   259                   1014
# 2         122              398                   258                   1049
# 3         115              394                   250                   1121
# 4         116              345                   242                   1151
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  327             148            803                     809
# 1                  346             142            835                     810
# 2                  362             164            904                     855
# 3                  333             157            875                     815
# 4                  329             156            824                     810
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            513  1647     1560                 1280            1013
# 1            575  1751     1665                 1372            1107
# 2            568  1779     1711                 1383            1089
# 3            536  1708     1660                 1358            1065
# 4            559  1702     1572                 1292            1030
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 622             174            736           430
# 1                 524             152            771           475
# 2                 577             164            814           458
# 3                 679             187            736           463
# 4                 766             197            766           429
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               110                  844                           1488
# 1               125                  901                           1470
# 2               129                  882                           1542
# 3               125                  866                           1627
# 4               116                  800                           1698
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              406           295                 850         217
# 1              422           254                 708         168
# 2              419           269                 727         159
# 3              451           302                 923         235
# 4              452           405                1163         300
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      345                   942       657
# 1                      329                  1032       534
# 2                      367                  1035       663
# 3                      371                   999       782
# 4                      380                   911       886
#
#    wristcircumference  wristheight  Gender SubjectsBirthLocation   DODRace  \
# 0                 152          756  Female               Germany     Black
# 1                 155          815  Female            California  Hispanic
# 2                 162          799  Female                 Texas     White
# 3                 173          818  Female  District of Columbia     Black
# 4                 152          762  Female                 Texas     White
#
#    Age WritingPreference
# 0   26        Right hand
# 1   21        Right hand
# 2   23        Right hand
# 3   22        Right hand
# 4   45        Right hand

# %%
df.SubjectsBirthLocation.value_counts()
# Out:
# California                417
# New York                  411
# Texas                     386
# Indiana                   264
# Illinois                  210
# Florida                   210
# Oklahoma                  205
# Michigan                  194
# Minnesota                 194
# Mississippi               193
# Georgia                   168
# Alabama                   164
# South Carolina            161
# North Carolina            145
# Ohio                      139
# Louisiana                 136
# Pennsylvania              130
# Virginia                  113
# Massachusetts             109
# Wisconsin                  99
# Germany                    90
# Puerto Rico                88
# New Jersey                 88
# Missouri                   83
# Maryland                   78
# Colorado                   78
# Arizona                    75
# Tennessee                  74
# Kentucky                   67
# Kansas                     62
# Washington                 61
# Iowa                       55
# South Dakota               53
# Arkansas                   53
# Oregon                     40
# Mexico                     39
# Connecticut                36
# Jamaica                    35
# Nebraska                   30
# Utah                       27
# West Virginia              26
# Nevada                     21
# Idaho                      20
# District of Columbia       19
# Hawaii                     18
# North Dakota               18
# Maine                      18
# Rhode Island               18
# Dominican Republic         17
# Delaware                   17
# New Mexico                 16
# New Hampshire              14
# Colombia                   13
# Vermont                    13
# Haiti                      12
# Montana                    12
# United Kingdom             11
# Panama                     10
# Canada                      8
# Peru                        8
# Guyana                      8
# Russia                      8
# US Virgin Islands           7
# Wyoming                     7
# Alaska                      7
# Japan                       7
# Trinidad and Tobago         7
# Ukraine                     7
# Liberia                     6
# Ecuador                     5
# Barbados                    5
# Poland                      5
# El Salvador                 5
# Philippines                 5
# Honduras                    4
# Grenada                     4
# Nicaragua                   4
# South Africa                4
# Cuba                        4
# Nigeria                     4
# Portugal                    4
# Romania                     3
# Guam                        3
# Belgium                     3
# France                      3
# Kenya                       3
# Morocco                     3
# Israel                      3
# United States               2
# Ghana                       2
# Turkey                      2
# Sudan                       2
# Netherlands                 2
# Belize                      2
# Italy                       2
# Sierra Leone                2
# Lebanon                     2
# Antigua and Barbuda         2
# Iraq                        2
# Bolivia                     2
# Costa Rica                  2
# Cameroon                    2
# Senegal                     1
# South America               1
# Guadalupe                   1
# Syria                       1
# Brazil                      1
# Cape Verde                  1
# Togo                        1
# India                       1
# New Zealand                 1
# Belarus                     1
# Ivory Coast                 1
# Ethiopia                    1
# Egypt                       1
# French Guiana               1
# Iran                        1
# Bahamas                     1
# Chile                       1
# Serbia                      1
# Dominica                    1
# Saint Lucia                 1
# Zambia                      1
# Argentina                   1
# Iceland                     1
# Paraguay                    1
# Bulgaria                    1
# British Virgin Islands      1
# Sri Lanka                   1
# Azerbaijan                  1
# Venezuela                   1
# Bosnia and Herzegovina      1
# Bermuda                     1
# Denmark                     1
# South Korea                 1
# Guatemala                   1
# Name: SubjectsBirthLocation, dtype: int64

# %% [markdown]
# Data Preprocessing For Linear Regression

# %%
dummy_data = pd.get_dummies(df, columns=['Gender', "WritingPreference"], drop_first=True)
#dummy_data = dummy_data.drop("SubjectsBirthLocation", axis=1, inplace=True)

# %%
dummy_data.head()
# Out:
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                             231            1282                    301
# 1                             194            1379                    320
# 2                             183            1369                    329
# 3                             261            1356                    306
# 4                             309            1303                    308
#
#    anklecircumference  axillaheight  balloffootcircumference  \
# 0                 204          1180                      222
# 1                 207          1292                      225
# 2                 233          1271                      237
# 3                 214          1250                      240
# 4                 214          1210                      217
#
#    balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 0               177                373                        315
# 1               178                372                        272
# 2               196                397                        300
# 3               188                384                        364
# 4               182                378                        320
#
#    bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  \
# 0               263               466                  65               338
# 1               250               430                  64               294
# 2               276               450                  69               309
# 3               276               484                  68               340
# 4               336               525                  67               300
#
#    bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  \
# 0                        301                 141                  1011
# 1                        270                 126                   893
# 2                        270                 128                   987
# 3                        294                 144                  1012
# 4                        295                 135                  1281
#
#    buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  \
# 0           223            836                587                     476
# 1           186            900                583                     483
# 2           204            861                583                     466
# 3           253            897                599                     471
# 4           284            811                607                     467
#
#    calfcircumference  cervicaleheight  chestbreadth  chestcircumference  \
# 0                360             1336           274                 922
# 1                350             1440           261                 839
# 2                384             1451           287                 874
# 3                372             1430           269                1008
# 4                433             1362           305                1089
#
#    chestdepth  chestheight  crotchheight  crotchlengthomphalion  \
# 0         245         1095           759                    557
# 1         206         1234           835                    549
# 2         223         1226           821                    643
# 3         285         1170           804                    640
# 4         290         1112           726                    686
#
#    crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 0                             310          35         65             16
# 1                             329          32         60             23
# 2                             374          36         65             26
# 3                             351          38         62             22
# 4                             356          34         65             18
#
#    elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 0              220               713                     91         246
# 1              208               726                     91         249
# 2              204               790                    100         265
# 3              244               775                     97         265
# 4              233               732                     88         247
#
#    forearmcenterofgriplength  forearmcircumferenceflexed  \
# 0                        316                         265
# 1                        341                         247
# 2                        343                         262
# 3                        331                         309
# 4                        339                         260
#
#    forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  \
# 0                    517                432                 1028           75
# 1                    468                463                 1117           78
# 2                    488                469                 1060           84
# 3                    529                455                 1069           80
# 4                    596                447                 1039           78
#
#    handcircumference  handlength  headbreadth  headcircumference  headlength  \
# 0                182         184          141                548         191
# 1                187         189          138                535         180
# 2                198         195          146                588         207
# 3                192         186          153                593         206
# 4                183         187          140                522         181
#
#    heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  \
# 0                     314           69         345                388
# 1                     307           60         315                335
# 2                     331           70         356                399
# 3                     332           68         337                402
# 4                     308           63         448                499
#
#    iliocristaleheight  interpupillarybreadth  interscyei  interscyeii  \
# 0                 966                    645         363          399
# 1                1048                    595         340          375
# 2                1043                    655         345          399
# 3                1029                    655         392          435
# 4                 964                    635         428          435
#
#    kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                   435                496                             447
# 1                   483                532                             492
# 2                   470                530                             469
# 3                   469                520                             478
# 4                   440                491                             441
#
#    lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  \
# 0                      55                      404                  118
# 1                      69                      334                  115
# 2                      64                      401                  135
# 3                      67                      402                  118
# 4                      63                      479                  114
#
#    neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  \
# 0                335                    368                           1268
# 1                302                    345                           1389
# 2                325                    369                           1414
# 3                357                    386                           1329
# 4                340                    358                           1350
#
#    palmlength  poplitealheight  radialestylionlength  shouldercircumference  \
# 0         113              362                   235                   1062
# 1         110              426                   259                   1014
# 2         122              398                   258                   1049
# 3         115              394                   250                   1121
# 4         116              345                   242                   1151
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  327             148            803                     809
# 1                  346             142            835                     810
# 2                  362             164            904                     855
# 3                  333             157            875                     815
# 4                  329             156            824                     810
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            513  1647     1560                 1280            1013
# 1            575  1751     1665                 1372            1107
# 2            568  1779     1711                 1383            1089
# 3            536  1708     1660                 1358            1065
# 4            559  1702     1572                 1292            1030
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 622             174            736           430
# 1                 524             152            771           475
# 2                 577             164            814           458
# 3                 679             187            736           463
# 4                 766             197            766           429
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               110                  844                           1488
# 1               125                  901                           1470
# 2               129                  882                           1542
# 3               125                  866                           1627
# 4               116                  800                           1698
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              406           295                 850         217
# 1              422           254                 708         168
# 2              419           269                 727         159
# 3              451           302                 923         235
# 4              452           405                1163         300
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      345                   942       657
# 1                      329                  1032       534
# 2                      367                  1035       663
# 3                      371                   999       782
# 4                      380                   911       886
#
#    wristcircumference  wristheight SubjectsBirthLocation   DODRace  Age  \
# 0                 152          756               Germany     Black   26
# 1                 155          815            California  Hispanic   21
# 2                 162          799                 Texas     White   23
# 3                 173          818  District of Columbia     Black   22
# 4                 152          762                 Texas     White   45
#
#    Gender_Male  WritingPreference_Left hand  WritingPreference_Right hand
# 0            0                            0                             1
# 1            0                            0                             1
# 2            0                            0                             1
# 3            0                            0                             1
# 4            0                            0                             1

# %%
dummy_data.drop("SubjectsBirthLocation", axis=1, inplace=True)
dummy_data
# Out:
#       abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                                231            1282                    301
# 1                                194            1379                    320
# 2                                183            1369                    329
# 3                                261            1356                    306
# 4                                309            1303                    308
# ...                              ...             ...                    ...
# 6063                             235            1353                    312
# 6064                             247            1473                    336
# 6065                             264            1394                    313
# 6066                             203            1417                    327
# 6067                             327            1523                    358
#
#       anklecircumference  axillaheight  balloffootcircumference  \
# 0                    204          1180                      222
# 1                    207          1292                      225
# 2                    233          1271                      237
# 3                    214          1250                      240
# 4                    214          1210                      217
# ...                  ...           ...                      ...
# 6063                 216          1263                      228
# 6064                 234          1346                      253
# 6065                 227          1280                      245
# 6066                 223          1314                      250
# 6067                 226          1408                      269
#
#       balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 0                  177                373                        315
# 1                  178                372                        272
# 2                  196                397                        300
# 3                  188                384                        364
# 4                  182                378                        320
# ...                ...                ...                        ...
# 6063               193                384                        318
# 6064               196                428                        374
# 6065               193                407                        367
# 6066               196                419                        365
# 6067               225                442                        379
#
#       bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  \
# 0                  263               466                  65
# 1                  250               430                  64
# 2                  276               450                  69
# 3                  276               484                  68
# 4                  336               525                  67
# ...                ...               ...                 ...
# 6063               241               457                  70
# 6064               284               536                  76
# 6065               271               501                  74
# 6066               271               493                  75
# 6067               275               531                  81
#
#       bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  \
# 0                  338                        301                 141
# 1                  294                        270                 126
# 2                  309                        270                 128
# 3                  340                        294                 144
# 4                  300                        295                 135
# ...                ...                        ...                 ...
# 6063               321                        301                 137
# 6064               319                        316                 135
# 6065               323                        316                 142
# 6066               342                        327                 138
# 6067               359                        364                 150
#
#       buttockcircumference  buttockdepth  buttockheight  buttockkneelength  \
# 0                     1011           223            836                587
# 1                      893           186            900                583
# 2                      987           204            861                583
# 3                     1012           253            897                599
# 4                     1281           284            811                607
# ...                    ...           ...            ...                ...
# 6063                   917           231            878                587
# 6064                  1049           252            899                632
# 6065                  1038           276            857                614
# 6066                   929           209            898                598
# 6067                  1009           254            981                659
#
#       buttockpopliteallength  calfcircumference  cervicaleheight  \
# 0                        476                360             1336
# 1                        483                350             1440
# 2                        466                384             1451
# 3                        471                372             1430
# 4                        467                433             1362
# ...                      ...                ...              ...
# 6063                     497                345             1444
# 6064                     517                399             1533
# 6065                     502                378             1469
# 6066                     499                389             1483
# 6067                     550                396             1595
#
#       chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  \
# 0              274                 922         245         1095           759
# 1              261                 839         206         1234           835
# 2              287                 874         223         1226           821
# 3              269                1008         285         1170           804
# 4              305                1089         290         1112           726
# ...            ...                 ...         ...          ...           ...
# 6063           266                 954         238         1231           807
# 6064           323                1072         242         1301           848
# 6065           290                1045         247         1263           787
# 6066           284                 984         228         1271           846
# 6067           308                1144         281         1349           931
#
#       crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  \
# 0                       557                             310          35
# 1                       549                             329          32
# 2                       643                             374          36
# 3                       640                             351          38
# 4                       686                             356          34
# ...                     ...                             ...         ...
# 6063                    606                             306          36
# 6064                    695                             378          35
# 6065                    668                             337          38
# 6066                    603                             314          37
# 6067                    637                             313          36
#
#       earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0            65             16              220               713
# 1            60             23              208               726
# 2            65             26              204               790
# 3            62             22              244               775
# 4            65             18              233               732
# ...         ...            ...              ...               ...
# 6063         61             22              195               762
# 6064         60             20              299               807
# 6065         62             26              257               784
# 6066         61             22              237               782
# 6067         61             24              214               780
#
#       footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                        91         246                        316
# 1                        91         249                        341
# 2                       100         265                        343
# 3                        97         265                        331
# 4                        88         247                        339
# ...                     ...         ...                        ...
# 6063                     95         255                        329
# 6064                    103         263                        341
# 6065                    101         263                        340
# 6066                     98         266                        322
# 6067                    111         295                        377
#
#       forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                            265                    517                432
# 1                            247                    468                463
# 2                            262                    488                469
# 3                            309                    529                455
# 4                            260                    596                447
# ...                          ...                    ...                ...
# 6063                         277                    533                460
# 6064                         327                    600                476
# 6065                         312                    540                455
# 6066                         299                    552                461
# 6067                         317                    601                519
#
#       functionalleglength  handbreadth  handcircumference  handlength  \
# 0                    1028           75                182         184
# 1                    1117           78                187         189
# 2                    1060           84                198         195
# 3                    1069           80                192         186
# 4                    1039           78                183         187
# ...                   ...          ...                ...         ...
# 6063                 1073           81                193         182
# 6064                 1088           94                222         191
# 6065                 1045           83                207         183
# 6066                 1091           92                218         192
# 6067                 1212           95                223         205
#
#       headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0             141                548         191                     314
# 1             138                535         180                     307
# 2             146                588         207                     331
# 3             153                593         206                     332
# 4             140                522         181                     308
# ...           ...                ...         ...                     ...
# 6063          151                554         187                     323
# 6064          149                558         196                     327
# 6065          148                555         194                     340
# 6066          150                560         197                     326
# 6067          153                615         220                     358
#
#       heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0              69         345                388                 966
# 1              60         315                335                1048
# 2              70         356                399                1043
# 3              68         337                402                1029
# 4              63         448                499                 964
# ...           ...         ...                ...                 ...
# 6063           69         301                353                1025
# 6064           67         356                395                1057
# 6065           74         334                362                1032
# 6066           65         320                352                1050
# 6067           72         339                371                1127
#
#       interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                       645         363          399                   435
# 1                       595         340          375                   483
# 2                       655         345          399                   470
# 3                       655         392          435                   469
# 4                       635         428          435                   440
# ...                     ...         ...          ...                   ...
# 6063                    595         405          422                   474
# 6064                    590         468          473                   491
# 6065                    560         434          450                   464
# 6066                    630         440          445                   480
# 6067                    695         457          482                   544
#
#       kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                   496                             447
# 1                   532                             492
# 2                   530                             469
# 3                   520                             478
# 4                   491                             441
# ...                 ...                             ...
# 6063                523                             476
# 6064                565                             510
# 6065                527                             466
# 6066                542                             489
# 6067                596                             536
#
#       lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  \
# 0                         55                      404                  118
# 1                         69                      334                  115
# 2                         64                      401                  135
# 3                         67                      402                  118
# 4                         63                      479                  114
# ...                      ...                      ...                  ...
# 6063                      68                      371                  123
# 6064                      67                      420                  117
# 6065                      71                      413                  118
# 6066                      70                      364                  123
# 6067                      70                      410                  136
#
#       neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  \
# 0                   335                    368                           1268
# 1                   302                    345                           1389
# 2                   325                    369                           1414
# 3                   357                    386                           1329
# 4                   340                    358                           1350
# ...                 ...                    ...                            ...
# 6063                378                    427                           1304
# 6064                392                    430                           1433
# 6065                416                    444                           1310
# 6066                387                    414                           1388
# 6067                439                    477                           1399
#
#       palmlength  poplitealheight  radialestylionlength  \
# 0            113              362                   235
# 1            110              426                   259
# 2            122              398                   258
# 3            115              394                   250
# 4            116              345                   242
# ...          ...              ...                   ...
# 6063         112              418                   259
# 6064         114              447                   265
# 6065         110              407                   257
# 6066         115              432                   254
# 6067         116              464                   295
#
#       shouldercircumference  shoulderelbowlength  shoulderlength  \
# 0                      1062                  327             148
# 1                      1014                  346             142
# 2                      1049                  362             164
# 3                      1121                  333             157
# 4                      1151                  329             156
# ...                     ...                  ...             ...
# 6063                   1096                  348             150
# 6064                   1199                  356             146
# 6065                   1181                  333             135
# 6066                   1162                  358             154
# 6067                   1231                  386             152
#
#       sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  \
# 0               803                     809            513  1647     1560
# 1               835                     810            575  1751     1665
# 2               904                     855            568  1779     1711
# 3               875                     815            536  1708     1660
# 4               824                     810            559  1702     1572
# ...             ...                     ...            ...   ...      ...
# 6063            883                     865            568  1688     1688
# 6064            938                     903            606  1818     1765
# 6065            895                     860            571  1642     1690
# 6066            900                     874            576  1760     1718
# 6067            896                     955            638  1885     1828
#
#       suprasternaleheight  tenthribheight  thighcircumference  thighclearance  \
# 0                    1280            1013                 622             174
# 1                    1372            1107                 524             152
# 2                    1383            1089                 577             164
# 3                    1358            1065                 679             187
# 4                    1292            1030                 766             197
# ...                   ...             ...                 ...             ...
# 6063                 1368            1079                 579             162
# 6064                 1456            1146                 662             171
# 6065                 1384            1096                 605             178
# 6066                 1405            1116                 544             170
# 6067                 1500            1208                 622             196
#
#       thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  \
# 0               736           430               110                  844
# 1               771           475               125                  901
# 2               814           458               129                  882
# 3               736           463               125                  866
# 4               766           429               116                  800
# ...             ...           ...               ...                  ...
# 6063            758           447               140                  869
# 6064            785           472               135                  886
# 6065            750           439               127                  858
# 6066            779           453               118                  886
# 6067            861           509               135                  970
#
#       verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  \
# 0                              1488              406           295
# 1                              1470              422           254
# 2                              1542              419           269
# 3                              1627              451           302
# 4                              1698              452           405
# ...                             ...              ...           ...
# 6063                           1557              442           279
# 6064                           1715              475           351
# 6065                           1682              483           333
# 6066                           1589              430           293
# 6067                           1764              511           354
#
#       waistcircumference  waistdepth  waistfrontlengthsitting  \
# 0                    850         217                      345
# 1                    708         168                      329
# 2                    727         159                      367
# 3                    923         235                      371
# 4                   1163         300                      380
# ...                  ...         ...                      ...
# 6063                 816         210                      347
# 6064                 978         235                      385
# 6065                 991         258                      353
# 6066                 783         192                      350
# 6067                1080         294                      389
#
#       waistheightomphalion  weightkg  wristcircumference  wristheight  \
# 0                      942       657                 152          756
# 1                     1032       534                 155          815
# 2                     1035       663                 162          799
# 3                      999       782                 173          818
# 4                      911       886                 152          762
# ...                    ...       ...                 ...          ...
# 6063                  1016       675                 163          778
# 6064                  1082       896                 178          873
# 6065                  1011       832                 178          822
# 6066                  1062       731                 172          837
# 6067                  1119       985                 182          894
#
#        DODRace  Age  Gender_Male  WritingPreference_Left hand  \
# 0        Black   26            0                            0
# 1     Hispanic   21            0                            0
# 2        White   23            0                            0
# 3        Black   22            0                            0
# 4        White   45            0                            0
# ...        ...  ...          ...                          ...
# 6063     White   22            1                            0
# 6064     White   22            1                            0
# 6065     White   23            1                            0
# 6066     White   22            1                            0
# 6067     White   38            1                            0
#
#       WritingPreference_Right hand
# 0                                1
# 1                                1
# 2                                1
# 3                                1
# 4                                1
# ...                            ...
# 6063                             1
# 6064                             1
# 6065                             1
# 6066                             1
# 6067                             1
#
# [5769 rows x 98 columns]

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %%
X = dummy_data.drop("DODRace",axis=1)
y = dummy_data.DODRace

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=101)

# %%
scaler = MinMaxScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train) # egitim 
X_test_scaled = scaler.transform(X_test) # dönüşüm

# %% [markdown]
# # Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %% [markdown]
# ## 1. Logistic model

# %% [markdown]
# ### Vanilla Logistic Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, plot_confusion_matrix

# %%
log_model = LogisticRegression()

# %%
log_model.fit(X_train_scaled,y_train)
y_pred = log_model.predict(X_test_scaled)
y_pred
# Out:
# array(['Black', 'White', 'White', ..., 'White', 'White', 'White'],
#       dtype=object)

# %%
plot_confusion_matrix(log_model, X_test_scaled, y_test)

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
eval_metric(log_model, X_train_scaled, y_train, X_test_scaled, y_test) # overfit yok.
# Out:
# Test_Set
# [[224   5  29]
#  [ 13  37  81]
#  [  6  14 745]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.87      0.89       258
#     Hispanic       0.66      0.28      0.40       131
#        White       0.87      0.97      0.92       765
#
#     accuracy                           0.87      1154
#    macro avg       0.82      0.71      0.74      1154
# weighted avg       0.86      0.87      0.85      1154
#
#
# Train_Set
# [[ 938   21   81]
#  [  54  181  313]
#  [  40   55 2932]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.90      0.91      1040
#     Hispanic       0.70      0.33      0.45       548
#        White       0.88      0.97      0.92      3027
#
#     accuracy                           0.88      4615
#    macro avg       0.83      0.73      0.76      4615
# weighted avg       0.87      0.88      0.86      4615

# %% [markdown]
# ### Logistic Model GridsearchCV

# %%
log_model = LogisticRegression(max_iter=5000)

# %%
penalty = ["l1", "l2"]
C = np.logspace(-1, 5, 20)

param_grid = {"penalty" : penalty,
             "C" : C}

# %%
grid_model = GridSearchCV(log_model, param_grid = param_grid, cv=5)

# %%
grid_model.fit(X_train_scaled,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(max_iter=5000),
#              param_grid={'C': array([1.00000000e-01, 2.06913808e-01, 4.28133240e-01, 8.85866790e-01,
#        1.83298071e+00, 3.79269019e+00, 7.84759970e+00, 1.62377674e+01,
#        3.35981829e+01, 6.95192796e+01, 1.43844989e+02, 2.97635144e+02,
#        6.15848211e+02, 1.27427499e+03, 2.63665090e+03, 5.45559478e+03,
#        1.12883789e+04, 2.33572147e+04, 4.83293024e+04, 1.00000000e+05]),
#                          'penalty': ['l1', 'l2']})

# %%
grid_model.best_params_
# Out:
# {'C': 7.847599703514611, 'penalty': 'l2'}

# %%
grid_model.best_params_
# Out:
# {'C': 7.847599703514611, 'penalty': 'l2'}

# %%
y_pred = grid_model.predict(X_test_scaled)
y_pred
# Out:
# array(['Black', 'White', 'White', ..., 'White', 'White', 'White'],
#       dtype=object)

# %%
plot_confusion_matrix(grid_model, X_test_scaled, y_test)

# %%
eval_metric(grid_model, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
# Test_Set
# [[230   6  22]
#  [ 14  44  73]
#  [  5  21 739]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.89      0.91       258
#     Hispanic       0.62      0.34      0.44       131
#        White       0.89      0.97      0.92       765
#
#     accuracy                           0.88      1154
#    macro avg       0.81      0.73      0.76      1154
# weighted avg       0.86      0.88      0.87      1154
#
#
# Train_Set
# [[ 957   22   61]
#  [  50  218  280]
#  [  37   71 2919]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.92      0.92      1040
#     Hispanic       0.70      0.40      0.51       548
#        White       0.90      0.96      0.93      3027
#
#     accuracy                           0.89      4615
#    macro avg       0.84      0.76      0.78      4615
# weighted avg       0.88      0.89      0.88      4615

# %% [markdown]
# ## 2. SVC

# %% [markdown]
# ### Vanilla SVC model

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report,confusion_matrix

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
operations = [("scaler", StandardScaler()), ("SVC", SVC(random_state=42))]
pipe_model = Pipeline(steps=operations)

# %%
pipe_model.fit(X_train, y_train)
eval_metric(pipe_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[232   3  23]
#  [ 14  17 100]
#  [  4   7 754]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.90      0.91       258
#     Hispanic       0.63      0.13      0.22       131
#        White       0.86      0.99      0.92       765
#
#     accuracy                           0.87      1154
#    macro avg       0.81      0.67      0.68      1154
# weighted avg       0.85      0.87      0.84      1154
#
#
# Train_Set
# [[ 968    7   65]
#  [  49  149  350]
#  [  16   12 2999]]
#               precision    recall  f1-score   support
#
#        Black       0.94      0.93      0.93      1040
#     Hispanic       0.89      0.27      0.42       548
#        White       0.88      0.99      0.93      3027
#
#     accuracy                           0.89      4615
#    macro avg       0.90      0.73      0.76      4615
# weighted avg       0.89      0.89      0.87      4615

# %% [markdown]
# ###  SVC Model GridsearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'SVC__C': [0.001, 0.05, 0.01, 0.1],
              'SVC__gamma': ["scale", "auto", 0.2, 0.3],
              'SVC__kernel': ['rbf', 'linear']}

# %%
operations = [("scaler", StandardScaler()), ("SVC", SVC(probability=True, class_weight="balanced", random_state=42))]
pipe_model = Pipeline(steps=operations)

svm_model_grid = GridSearchCV(pipe_model, param_grid, scoring="recall", cv=10)

# %%
svm_model_grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('SVC',
#                                         SVC(class_weight='balanced',
#                                             probability=True,
#                                             random_state=42))]),
#              param_grid={'SVC__C': [0.001, 0.05, 0.01, 0.1],
#                          'SVC__gamma': ['scale', 'auto', 0.2, 0.3],
#                          'SVC__kernel': ['rbf', 'linear']},
#              scoring='recall')

# %%
svm_model_grid.best_score_
# Out:
# nan

# %%
eval_metric(svm_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[258   0   0]
#  [131   0   0]
#  [765   0   0]]
#               precision    recall  f1-score   support
#
#        Black       0.22      1.00      0.37       258
#     Hispanic       0.00      0.00      0.00       131
#        White       0.00      0.00      0.00       765
#
#     accuracy                           0.22      1154
#    macro avg       0.07      0.33      0.12      1154
# weighted avg       0.05      0.22      0.08      1154
#
#
# Train_Set
# [[1040    0    0]
#  [ 548    0    0]
#  [3027    0    0]]
#               precision    recall  f1-score   support
#
#        Black       0.23      1.00      0.37      1040
#     Hispanic       0.00      0.00      0.00       548
#        White       0.00      0.00      0.00      3027
#
#     accuracy                           0.23      4615
#    macro avg       0.08      0.33      0.12      4615
# weighted avg       0.05      0.23      0.08      4615

# %% [markdown]
# ## 3. RF

# %% [markdown]
# ### Vanilla RF Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
cat = df.select_dtypes("object").columns
cat
# Out:
# Index(['Gender', 'SubjectsBirthLocation', 'DODRace', 'WritingPreference'], dtype='object')

# %%
enc = OrdinalEncoder()
df[cat] = enc.fit_transform(df[cat])
df.head()
# Out:
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                             231            1282                    301
# 1                             194            1379                    320
# 2                             183            1369                    329
# 3                             261            1356                    306
# 4                             309            1303                    308
#
#    anklecircumference  axillaheight  balloffootcircumference  \
# 0                 204          1180                      222
# 1                 207          1292                      225
# 2                 233          1271                      237
# 3                 214          1250                      240
# 4                 214          1210                      217
#
#    balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 0               177                373                        315
# 1               178                372                        272
# 2               196                397                        300
# 3               188                384                        364
# 4               182                378                        320
#
#    bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  \
# 0               263               466                  65               338
# 1               250               430                  64               294
# 2               276               450                  69               309
# 3               276               484                  68               340
# 4               336               525                  67               300
#
#    bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  \
# 0                        301                 141                  1011
# 1                        270                 126                   893
# 2                        270                 128                   987
# 3                        294                 144                  1012
# 4                        295                 135                  1281
#
#    buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  \
# 0           223            836                587                     476
# 1           186            900                583                     483
# 2           204            861                583                     466
# 3           253            897                599                     471
# 4           284            811                607                     467
#
#    calfcircumference  cervicaleheight  chestbreadth  chestcircumference  \
# 0                360             1336           274                 922
# 1                350             1440           261                 839
# 2                384             1451           287                 874
# 3                372             1430           269                1008
# 4                433             1362           305                1089
#
#    chestdepth  chestheight  crotchheight  crotchlengthomphalion  \
# 0         245         1095           759                    557
# 1         206         1234           835                    549
# 2         223         1226           821                    643
# 3         285         1170           804                    640
# 4         290         1112           726                    686
#
#    crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# 0                             310          35         65             16
# 1                             329          32         60             23
# 2                             374          36         65             26
# 3                             351          38         62             22
# 4                             356          34         65             18
#
#    elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# 0              220               713                     91         246
# 1              208               726                     91         249
# 2              204               790                    100         265
# 3              244               775                     97         265
# 4              233               732                     88         247
#
#    forearmcenterofgriplength  forearmcircumferenceflexed  \
# 0                        316                         265
# 1                        341                         247
# 2                        343                         262
# 3                        331                         309
# 4                        339                         260
#
#    forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  \
# 0                    517                432                 1028           75
# 1                    468                463                 1117           78
# 2                    488                469                 1060           84
# 3                    529                455                 1069           80
# 4                    596                447                 1039           78
#
#    handcircumference  handlength  headbreadth  headcircumference  headlength  \
# 0                182         184          141                548         191
# 1                187         189          138                535         180
# 2                198         195          146                588         207
# 3                192         186          153                593         206
# 4                183         187          140                522         181
#
#    heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  \
# 0                     314           69         345                388
# 1                     307           60         315                335
# 2                     331           70         356                399
# 3                     332           68         337                402
# 4                     308           63         448                499
#
#    iliocristaleheight  interpupillarybreadth  interscyei  interscyeii  \
# 0                 966                    645         363          399
# 1                1048                    595         340          375
# 2                1043                    655         345          399
# 3                1029                    655         392          435
# 4                 964                    635         428          435
#
#    kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  \
# 0                   435                496                             447
# 1                   483                532                             492
# 2                   470                530                             469
# 3                   469                520                             478
# 4                   440                491                             441
#
#    lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  \
# 0                      55                      404                  118
# 1                      69                      334                  115
# 2                      64                      401                  135
# 3                      67                      402                  118
# 4                      63                      479                  114
#
#    neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  \
# 0                335                    368                           1268
# 1                302                    345                           1389
# 2                325                    369                           1414
# 3                357                    386                           1329
# 4                340                    358                           1350
#
#    palmlength  poplitealheight  radialestylionlength  shouldercircumference  \
# 0         113              362                   235                   1062
# 1         110              426                   259                   1014
# 2         122              398                   258                   1049
# 3         115              394                   250                   1121
# 4         116              345                   242                   1151
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  327             148            803                     809
# 1                  346             142            835                     810
# 2                  362             164            904                     855
# 3                  333             157            875                     815
# 4                  329             156            824                     810
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            513  1647     1560                 1280            1013
# 1            575  1751     1665                 1372            1107
# 2            568  1779     1711                 1383            1089
# 3            536  1708     1660                 1358            1065
# 4            559  1702     1572                 1292            1030
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 622             174            736           430
# 1                 524             152            771           475
# 2                 577             164            814           458
# 3                 679             187            736           463
# 4                 766             197            766           429
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               110                  844                           1488
# 1               125                  901                           1470
# 2               129                  882                           1542
# 3               125                  866                           1627
# 4               116                  800                           1698
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              406           295                 850         217
# 1              422           254                 708         168
# 2              419           269                 727         159
# 3              451           302                 923         235
# 4              452           405                1163         300
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      345                   942       657
# 1                      329                  1032       534
# 2                      367                  1035       663
# 3                      371                   999       782
# 4                      380                   911       886
#
#    wristcircumference  wristheight  Gender  SubjectsBirthLocation  DODRace  \
# 0                 152          756   0.000                 41.000    0.000
# 1                 155          815   0.000                 18.000    1.000
# 2                 162          799   0.000                119.000    2.000
# 3                 173          818   0.000                 30.000    0.000
# 4                 152          762   0.000                119.000    2.000
#
#    Age  WritingPreference
# 0   26              2.000
# 1   21              2.000
# 2   23              2.000
# 3   22              2.000
# 4   45              2.000

# %%
X = df.drop('DODRace',axis=1)
y = df['DODRace']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
rf_model = RandomForestClassifier(random_state=101)
rf_model.fit(X_train,y_train)
eval_metric(rf_model, X_train, y_train, X_test, y_test) # overfit!!!
# Out:
# Test_Set
# [[ 291    1  105]
#  [  22   11  167]
#  [  27    4 1103]]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.73      0.79       397
#          1.0       0.69      0.06      0.10       200
#          2.0       0.80      0.97      0.88      1134
#
#     accuracy                           0.81      1731
#    macro avg       0.78      0.59      0.59      1731
# weighted avg       0.80      0.81      0.77      1731
#
#
# Train_Set
# [[ 901    0    0]
#  [   0  479    0]
#  [   0    0 2658]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       901
#          1.0       1.00      1.00      1.00       479
#          2.0       1.00      1.00      1.00      2658
#
#     accuracy                           1.00      4038
#    macro avg       1.00      1.00      1.00      4038
# weighted avg       1.00      1.00      1.00      4038

# %% [markdown]
# ### RF Model GridsearchCV

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
param_grid = {"n_estimators":[64, 128, 200, 500],     
              "max_depth": [None, 4, 5, 6, 7,8],
              "min_samples_leaf": [1, 2, 3, 4],
              "min_samples_split": [2, 3, 5, 6],
              "max_features":['auto', len(df.columns)/3, 2, 4]}

# %%
grid_model = GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          scoring='neg_root_mean_squared_error',
                          cv=10,
                          n_jobs = -1)

# %%
grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [None, 4, 5, 6, 7, 8],
#                          'max_features': ['auto', 32.666666666666664, 2, 4],
#                          'min_samples_leaf': [1, 2, 3, 4],
#                          'min_samples_split': [2, 3, 5, 6],
#                          'n_estimators': [64, 128, 200, 500]},
#              scoring='neg_root_mean_squared_error')

# %%
grid_model.best_params_
# Out:
# {'max_depth': None,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 200}

# %%
eval_metric(grid_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[ 287    3  107]
#  [  26    7  167]
#  [  20    5 1109]]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.72      0.79       397
#          1.0       0.47      0.04      0.07       200
#          2.0       0.80      0.98      0.88      1134
#
#     accuracy                           0.81      1731
#    macro avg       0.71      0.58      0.58      1731
# weighted avg       0.78      0.81      0.77      1731
#
#
# Train_Set
# [[ 901    0    0]
#  [   0  479    0]
#  [   0    0 2658]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       901
#          1.0       1.00      1.00      1.00       479
#          2.0       1.00      1.00      1.00      2658
#
#     accuracy                           1.00      4038
#    macro avg       1.00      1.00      1.00      4038
# weighted avg       1.00      1.00      1.00      4038

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# ### Vanilla XGBoost Model

# %%
pip install xgboost
# Out:
# Collecting xgboostNote: you may need to restart the kernel to use updated packages.
#
#   Downloading xgboost-1.5.2-py3-none-win_amd64.whl (106.6 MB)
# Requirement already satisfied: numpy in d:\anaconda3\lib\site-packages (from xgboost) (1.20.3)
# Requirement already satisfied: scipy in d:\anaconda3\lib\site-packages (from xgboost) (1.7.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.5.2

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier(random_state=42).fit(X_train, y_train)
# Out:
# [14:55:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
eval_metric(xgb, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[ 338    3   56]
#  [  13   60  127]
#  [  19   12 1103]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.85      0.88       397
#          1.0       0.80      0.30      0.44       200
#          2.0       0.86      0.97      0.91      1134
#
#     accuracy                           0.87      1731
#    macro avg       0.86      0.71      0.74      1731
# weighted avg       0.86      0.87      0.85      1731
#
#
# Train_Set
# [[ 901    0    0]
#  [   0  479    0]
#  [   0    0 2658]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       901
#          1.0       1.00      1.00      1.00       479
#          2.0       1.00      1.00      1.00      2658
#
#     accuracy                           1.00      4038
#    macro avg       1.00      1.00      1.00      4038
# weighted avg       1.00      1.00      1.00      4038

# %% [markdown]
# ### XGBoost Model GridsearchCV

# %%
param_grid = {"n_estimators":[50, 100, 200],'max_depth':[3,4,5], "learning_rate": [0.1, 0.2],
             "subsample":[0.5, 0.8, 1], "colsample_bytree":[0.5,0.7, 1]}

# %%
xgb_model = XGBClassifier(random_state=42)

# %%
xgb_grid = GridSearchCV(xgb_model, param_grid, scoring = "f1", verbose=2, n_jobs = -1).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# [15:11:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
xgb_grid.best_params_
# Out:
# {'colsample_bytree': 0.5,
#  'learning_rate': 0.1,
#  'max_depth': 3,
#  'n_estimators': 50,
#  'subsample': 0.5}

# %%
xgb_grid.best_score_
# Out:
# nan

# %%
eval_metric(xgb_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[ 289    1  107]
#  [  18   25  157]
#  [  22    4 1108]]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.73      0.80       397
#          1.0       0.83      0.12      0.22       200
#          2.0       0.81      0.98      0.88      1134
#
#     accuracy                           0.82      1731
#    macro avg       0.84      0.61      0.63      1731
# weighted avg       0.83      0.82      0.79      1731
#
#
# Train_Set
# [[ 747    2  152]
#  [  33  113  333]
#  [  28    7 2623]]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.83      0.87       901
#          1.0       0.93      0.24      0.38       479
#          2.0       0.84      0.99      0.91      2658
#
#     accuracy                           0.86      4038
#    macro avg       0.90      0.68      0.72      4038
# weighted avg       0.87      0.86      0.84      4038

# %% [markdown]
# ---
# ---

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Before the Deployment
# - Choose the model that works best based on your chosen metric
# - For final step, fit the best model with whole dataset to get better performance.
# - And your model ready to deploy, dump your model and scaler.

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
